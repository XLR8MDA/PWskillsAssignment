# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.
# Matplotlib is a Python data visualization library that provides a wide range of tools for creating various types of plots, graphs, and charts. It is one of the most widely used libraries for data visualization in Python and is open-source software. Matplotlib is used to visualize data in a clear and informative way, helping users to better understand patterns, relationships, and trends in their data.
# Five plots that can be plotted using the Pyplot module of Matplotlib are:
# 1.Line plot
# 2.Scatter plot
# 3.Bar plot
# 4.Histogram
# 5.Box plot

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.
#
# A scatter plot is a type of plot that is used to display the relationship between two variables. Each data point is represented by a dot, and the position of the dot on the plot represents the values of the two variables.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x, y)
plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
#
# The subplot() function in Matplotlib is used to create multiple plots on a single figure. It allows us to create a grid of plots and specify the location of each plot within the grid. This is useful when we want to compare different datasets or visualize different aspects of the same dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

fig, axs = plt.subplots(2, 2)


axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Line 1')


axs[0, 1].plot(x2, y2)
axs[0, 1].set_title('Line 2')


axs[1, 0].plot(x3, y3)
axs[1, 0].set_title('Line 3')

axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Line 4')

plt.subplots_adjust(wspace=0.3, hspace=0.5)

fig.suptitle('Four Line Plots')


plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])
#
# A bar plot is a type of plot that represents categorical data with rectangular bars with lengths proportional to the values that they represent.
# Bar plots are often used to:
# 1.Compare values across different categories.
# 2.Show changes in data over time.
# 3.Show the distribution of data within each category.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the bar plot
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Plot a bar plot
plt.bar(company, profit)
plt.title('Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit (in millions)')
plt.show()

# Plot a horizontal bar plot
plt.barh(company, profit)
plt.title('Company Profits')
plt.xlabel('Profit (in millions)')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)
#
# A box plot is a type of plot that displays the distribution of a dataset by showing the median, quartiles, and outliers. Box plots can be used to identify the range, skewness, and outliers in a dataset.
# Box plots are often used to:
# 1.Show the distribution of a dataset.
# 2.Identify the median, quartiles, and outliers in a dataset.
# 3.Compare the distribution of multiple datasets.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the box plot
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = [box1, box2]

# Plot a box plot
plt.boxplot(data)
plt.title('Box Plot')
plt.xlabel('Data')
plt.ylabel('Values')
plt.show()
